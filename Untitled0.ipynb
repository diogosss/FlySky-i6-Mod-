# %% [markdown]
# <a href="https://colab.research.google.com/github/diogosss/FlySky-i6-Mod-/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TEST1

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
from numpy.random import randn
from time import sleep
import numpy as np

for i in range(5):
  plt.imshow(randn(28, 28))
  print(type(plt.imshow(randn(28, 28))))
  plt.show()
  sleep(0.5)
  clear_output(wait=True)
# Out:
# <class 'matplotlib.image.AxesImage'>

# %% [markdown]
# # ORIGINAL

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np
from time import sleep

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.cos(w*t) * (np.sin(0) + 1j*np.cos(0))
Bbb = np.cos(w*t-2*np.pi/3) * (np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3))
Bcc = np.cos(w*t+2*np.pi/3) * (np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

figure, axes = plt.subplots( 1 ) 
axes.plot(x,y) 
axes.set_aspect(1) 
plt.xlim(-2,2)
plt.ylim(-2,2)
plt.title( 'El campo magnético giratorio' ) 
plt.xlabel('Densidad de flujo (T)')
plt.ylabel('Densidad de flujo (T)')


Baa_ref = 1.5 * np.round((np.sin(0) + 1j*np.cos(0)),4)
Bbb_ref = 1.5 * np.round((np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3)),4)

axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

ii=0;

h1, = axes.plot([0,Baa[ii].real], [0,Baa[ii].imag], c = 'black', linewidth = 2.5)
h2, = axes.plot([0,Bbb[ii].real], [0,Bbb[ii].imag], c = 'b', linewidth = 2.5)
h3, = axes.plot([0,Bcc[ii].real], [0,Bcc[ii].imag], c = 'r', linewidth = 2.5)
h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)

for ii in range(1,len(t)):
    h1.set_xdata([0,Baa[ii].real])
    h1.set_ydata([0,Baa[ii].imag])
    h2.set_xdata([0,Bbb[ii].real])
    h2.set_ydata([0,Bbb[ii].imag])
    h3.set_xdata([0,Bcc[ii].real])
    h3.set_ydata([0,Bcc[ii].imag])
    h4.set_xdata([0,Bnet[ii].real])
    h4.set_ydata([0,Bnet[ii].imag])
    figure.canvas.draw()
    figure.canvas.flush_events()

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.sin(w*t) * (np.cos(0) + 1j*np.sin(0))
Bbb = np.sin(w*t-2*np.pi/3) * (np.cos(2*np.pi/3) + 1j*np.sin(2*np.pi/3))
Bcc = np.sin(w*t+2*np.pi/3) * (np.cos(-2*np.pi/3) + 1j*np.sin(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

plt.cla()
axes.plot(x,y) 
axes.set_aspect(1) 
plt.xlim(-2,2)
plt.ylim(-2,2)
plt.title( 'El campo magnético giratorio' ) 
plt.xlabel('Densidad de flujo (T)')
plt.ylabel('Densidad de flujo (T)')

Baa_ref = 1.5 * np.round((np.cos(0) + 1j*np.sin(0)),4)
Bbb_ref = 1.5 * np.round((np.cos(2*np.pi/3) + 1j*np.sin(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.cos(-2*np.pi/3) + 1j*np.sin(-2*np.pi/3)),4)

axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes.text(1.55 * np.cos(0), 1.55 * np.sin(0), 'B(aa)')
axes.text(1.55 * np.cos(2*np.pi/3)-0.2, 1.55 * np.sin(2*np.pi/3), 'B(bb)')
axes.text(1.55 * np.cos(-2*np.pi/3) -0.2, 1.55 * np.sin(-2*np.pi/3), 'B(cc)')

ii=0;

h1, = axes.plot([0,Baa[ii].real], [0,Baa[ii].imag], c = 'black', linewidth = 2.5)
h2, = axes.plot([0,Bbb[ii].real], [0,Bbb[ii].imag], c = 'b', linewidth = 2.5)
h3, = axes.plot([0,Bcc[ii].real], [0,Bcc[ii].imag], c = 'r', linewidth = 2.5)
h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)

for ii in range(1,len(t)):
    h1.set_xdata([0,Baa[ii].real])
    h1.set_ydata([0,Baa[ii].imag])
    h2.set_xdata([0,Bbb[ii].real])
    h2.set_ydata([0,Bbb[ii].imag])
    h3.set_xdata([0,Bcc[ii].real])
    h3.set_ydata([0,Bcc[ii].imag])
    h4.set_xdata([0,Bnet[ii].real])
    h4.set_ydata([0,Bnet[ii].imag])
    print(type(figure))
    figure.canvas.draw()
    figure.canvas.flush_events()

# %% [markdown]
# # Funcional 1   ✅

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np
from time import sleep

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.cos(w*t) * (np.sin(0) + 1j*np.cos(0))
Bbb = np.cos(w*t-2*np.pi/3) * (np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3))
Bcc = np.cos(w*t+2*np.pi/3) * (np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

figure, axes = plt.subplots( 1 ) 
axes.plot(x,y) 
axes.set_aspect(1) 
plt.xlim(-2,2)
plt.ylim(-2,2)
plt.title( 'El campo magnético giratorio' ) 
plt.xlabel('Densidad de flujo (T)')
plt.ylabel('Densidad de flujo (T)')


Baa_ref = 1.5 * np.round((np.sin(0) + 1j*np.cos(0)),4)
Bbb_ref = 1.5 * np.round((np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3)),4)

axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

ii=0;

h1, = axes.plot([0,Baa[ii].real], [0,Baa[ii].imag], c = 'black', linewidth = 2.5)
h2, = axes.plot([0,Bbb[ii].real], [0,Bbb[ii].imag], c = 'b', linewidth = 2.5)
h3, = axes.plot([0,Bcc[ii].real], [0,Bcc[ii].imag], c = 'r', linewidth = 2.5)
h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)

for ii in range(1,len(t)):
  h1.set_xdata([0,Baa[ii].real])
  h1.set_ydata([0,Baa[ii].imag])
  h2.set_xdata([0,Bbb[ii].real])
  h2.set_ydata([0,Bbb[ii].imag])
  h3.set_xdata([0,Bcc[ii].real])
  h3.set_ydata([0,Bcc[ii].imag])
  h4.set_xdata([0,Bnet[ii].real])
  h4.set_ydata([0,Bnet[ii].imag])
  figure.canvas.draw()
  figure.canvas.flush_events()
  image = np.frombuffer(figure.canvas.tostring_rgb(), dtype='uint8')
  image = image.reshape(figure.canvas.get_width_height()[::-1] + (3,))
  # show numpy array
  plt.imshow(image)
  plt.show()
  #sleep(1)
  clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/matplotlib/font_manager.py in set_stretch(self, stretch)
#     805         try:
# --> 806             stretch = int(stretch)
#     807             if stretch < 0 or stretch > 1000:
#
# ValueError: invalid literal for int() with base 10: 'normal'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-69884fe09e2e> in <module>()
#      67   # show numpy array
#      68   plt.imshow(image)
# ---> 69   plt.show()
#      70   #sleep(1)
#      71   clear_output(wait=True)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# ...

# %% [markdown]
# # TEST

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np 

x = np.linspace(0, 10, 100)
y = np.cos(x)

z = np.linspace(0, 10, 100)
w = np.sin(z)

fig = plt.figure()

for p in range(50):
    p=3
    updated_x=x+p
    updated_y=np.cos(x)
    plt.plot(updated_x,updated_y)
    updated_z=z+p
    updated_w=np.sin(w)
    plt.plot(updated_z,updated_w)
    plt.draw()  
    x=updated_x
    y=updated_y
    z=updated_z
    w=updated_w
    plt.pause(0.2)
    fig.clear()
    clear_output(wait=True)

# %% [markdown]
# # NO FUNCIONAL ERROR  ❌
# ---

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np
from time import sleep

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.cos(w*t) * (np.sin(0) + 1j*np.cos(0))
Bbb = np.cos(w*t-2*np.pi/3) * (np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3))
Bcc = np.cos(w*t+2*np.pi/3) * (np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

figure, axes = plt.subplots( 1 ) 
axes.plot(x,y) 
axes.set_aspect(1) 
plt.xlim(-2,2)
plt.ylim(-2,2)
plt.title( 'El campo magnético giratorio' ) 
plt.xlabel('Densidad de flujo (T)')
plt.ylabel('Densidad de flujo (T)')


Baa_ref = 1.5 * np.round((np.sin(0) + 1j*np.cos(0)),4)
Bbb_ref = 1.5 * np.round((np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3)),4)

axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

ii=0;

h1, = axes.plot([0,Baa[ii].real], [0,Baa[ii].imag], c = 'black', linewidth = 2.5)
h2, = axes.plot([0,Bbb[ii].real], [0,Bbb[ii].imag], c = 'b', linewidth = 2.5)
h3, = axes.plot([0,Bcc[ii].real], [0,Bcc[ii].imag], c = 'r', linewidth = 2.5)
h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)

print(type(h1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-81a142d3a9e8> in <module>()
#      52 h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)
#      53
# ---> 54 print(type(h1[0]))
#
# TypeError: 'Line2D' object is not subscriptable

# %% [markdown]
# # TEST EN ORIGINAL ERROR  ❌

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np
from time import sleep

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.cos(w*t) * (np.sin(0) + 1j*np.cos(0))
Bbb = np.cos(w*t-2*np.pi/3) * (np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3))
Bcc = np.cos(w*t+2*np.pi/3) * (np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

figure, axes = plt.subplots( 1 ) 
axes.plot(x,y) 
axes.set_aspect(1) 
plt.xlim(-2,2)
plt.ylim(-2,2)
plt.title( 'El campo magnético giratorio' ) 
plt.xlabel('Densidad de flujo (T)')
plt.ylabel('Densidad de flujo (T)')


Baa_ref = 1.5 * np.round((np.sin(0) + 1j*np.cos(0)),4)
Bbb_ref = 1.5 * np.round((np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3)),4)

axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

ii=0;

h1, = axes.plot([0,Baa[ii].real], [0,Baa[ii].imag], c = 'black', linewidth = 2.5)
h2, = axes.plot([0,Bbb[ii].real], [0,Bbb[ii].imag], c = 'b', linewidth = 2.5)
h3, = axes.plot([0,Bcc[ii].real], [0,Bcc[ii].imag], c = 'r', linewidth = 2.5)
h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)

for ii in range(1,len(t)):
  """
  h1.set_xdata([0,Baa[ii].real])
  h1.set_ydata([0,Baa[ii].imag])
  h2.set_xdata([0,Bbb[ii].real])
  h2.set_ydata([0,Bbb[ii].imag])
  h3.set_xdata([0,Bcc[ii].real])
  h3.set_ydata([0,Bcc[ii].imag])
  h4.set_xdata([0,Bnet[ii].real])
  h4.set_ydata([0,Bnet[ii].imag])
  """
  figure, axes = plt.subplots( 1 ) 
  axes.plot(x,y, c='cyan', linewidth = 2.5) 
  axes.set_aspect(1) 
  axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
  axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
  axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')
  axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
  axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
  axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

  plt.title( 'El campo magnético giratorio' ) 
  plt.xlabel('Densidad de flujo (T)')
  plt.ylabel('Densidad de flujo (T)')
  axes.plot(x,y) 
  axes.set_aspect(1) 
  plt.xlim(-2,2)
  plt.ylim(-2,2)
  h1x = [0,Baa[ii].real]
  h1y = [0,Baa[ii].imag]
  h2x = [0,Bbb[ii].real]
  h2y = [0,Bbb[ii].imag]
  h3x = [0,Bcc[ii].real]
  h3y = [0,Bcc[ii].imag]
  h4x = [0,Bnet[ii].real]
  h4y = [0,Bnet[ii].imag]
  plt.plot(h1x,h1y, c = 'black', linewidth = 2.5)
  plt.plot(h2x,h2y, c = 'b', linewidth = 2.5)
  plt.plot(h3x,h3y, c = 'r', linewidth = 2.5)
  plt.plot(h4x,h4y, c = 'y', linewidth = 2.5)
  # show numpy array
  #plt.imshow(image)
  plt.show()
  #sleep(1)
  clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-dac840ead5c4> in <module>()
#      97   # show numpy array
#      98   #plt.imshow(image)
# ---> 99   plt.show()
#     100   #sleep(1)
#     101   clear_output(wait=True)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
# ...

# %% [markdown]
# # TEST ORIGINAL 2 ERROR  ❌

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np
from time import sleep

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.cos(w*t) * (np.sin(0) + 1j*np.cos(0))
Bbb = np.cos(w*t-2*np.pi/3) * (np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3))
Bcc = np.cos(w*t+2*np.pi/3) * (np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

figure, axes = plt.subplots( 1 ) 
axes.plot(x,y) 
axes.set_aspect(1) 
plt.xlim(-2,2)
plt.ylim(-2,2)
plt.title( 'El campo magnético giratorio' ) 
plt.xlabel('Densidad de flujo (T)')
plt.ylabel('Densidad de flujo (T)')


Baa_ref = 1.5 * np.round((np.sin(0) + 1j*np.cos(0)),4)
Bbb_ref = 1.5 * np.round((np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3)),4)

axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

ii=0;

h1, = axes.plot([0,Baa[ii].real], [0,Baa[ii].imag], c = 'black', linewidth = 2.5)
h2, = axes.plot([0,Bbb[ii].real], [0,Bbb[ii].imag], c = 'b', linewidth = 2.5)
h3, = axes.plot([0,Bcc[ii].real], [0,Bcc[ii].imag], c = 'r', linewidth = 2.5)
h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)
ax = figure.add_subplot(111)
ax.add_line(h1)

for ii in range(1,len(t)):
  
  ax.set_xlim([0,Baa[ii].real])
  ax.set_xlim([0,Baa[ii].imag])
  """
  h2.set_xdata([0,Bbb[ii].real])
  h2.set_ydata([0,Bbb[ii].imag])
  h3.set_xdata([0,Bcc[ii].real])
  h3.set_ydata([0,Bcc[ii].imag])
  h4.set_xdata([0,Bnet[ii].real])
  h4.set_ydata([0,Bnet[ii].imag])
  """
  circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
  x = circle.real
  y = circle.imag
  figure, axes = plt.subplots( 1 ) 
  axes.plot(x,y) 
  axes.set_aspect(1) 
  axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
  axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
  axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')
  axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
  axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
  axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

  plt.title( 'El campo magnético giratorio' ) 
  plt.xlabel('Densidad de flujo (T)')
  plt.ylabel('Densidad de flujo (T)')
  axes.plot(x,y) 
  axes.set_aspect(1) 
  plt.xlim(-2,2)
  plt.ylim(-2,2)


  # show numpy array
  #plt.imshow(image)
  plt.show()
  #sleep(1)
  clear_output(wait=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-66754617ecc4> in <module>()
#      52 h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)
#      53 ax = figure.add_subplot(111)
# ---> 54 ax.add_line(h1)
#      55
#      56 for ii in range(1,len(t)):
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1844         Add a `.Line2D` to the axes' lines; return the line.
#    1845         """
# -> 1846         self._set_artist_props(line)
#    1847         if line.get_clip_path() is None:
#    1848             line.set_clip_path(self.patch)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in _set_artist_props(self, a)
#     907             a.set_transform(self.transData)
#     908
# --> 909         a.axes = self
#     910         if a.mouseover:
# ...

# %% [markdown]
# # TEST

# %%
import matplotlib.pyplot as plt

from matplotlib.lines import Line2D      

fig = plt.figure()

ax = fig.add_subplot(111)

x = [10,24,23,23,3]

y = [12,2,3,4,2]

line = Line2D(x, y)

ax.add_line(line)
#Out[21]: <matplotlib.lines.Line2D at 0x7f4c10732f60>

ax.set_xlim(min(x), max(x))
#Out[22]: (3, 24)

ax.set_ylim(min(y), max(y))
#Out[23]: (2, 12)

plt.show()

# %% [markdown]
# # FINAL FUNCIONAL     ✅

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np
from time import sleep

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.cos(w*t) * (np.sin(0) + 1j*np.cos(0))
Bbb = np.cos(w*t-2*np.pi/3) * (np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3))
Bcc = np.cos(w*t+2*np.pi/3) * (np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

figure, axes = plt.subplots( 1 ) 
axes.plot(x,y) 
axes.set_aspect(1) 


Baa_ref = 1.5 * np.round((np.sin(0) + 1j*np.cos(0)),4)
Bbb_ref = 1.5 * np.round((np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3)),4)


ii=0;


for ii in range(1,len(t)):
  figure, axes = plt.subplots( 1 ) 
  axes.plot(x,y, c='cyan', linewidth = 2.5) 
  axes.set_aspect(1) 
  axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
  axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
  axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')
  axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
  axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
  axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

  plt.title( 'El campo magnético giratorio' ) 
  plt.xlabel('Densidad de flujo (T)')
  plt.ylabel('Densidad de flujo (T)')
  axes.plot(x,y) 
  axes.set_aspect(1) 
  plt.xlim(-2,2)
  plt.ylim(-2,2)
  h1x = [0,Baa[ii].real]
  h1y = [0,Baa[ii].imag]
  h2x = [0,Bbb[ii].real]
  h2y = [0,Bbb[ii].imag]
  h3x = [0,Bcc[ii].real]
  h3y = [0,Bcc[ii].imag]
  h4x = [0,Bnet[ii].real]
  h4y = [0,Bnet[ii].imag]
  plt.plot(h1x,h1y, c = 'black', linewidth = 2.5)
  plt.plot(h2x,h2y, c = 'b', linewidth = 2.5)
  plt.plot(h3x,h3y, c = 'r', linewidth = 2.5)
  plt.plot(h4x,h4y, c = 'y', linewidth = 2.5)
  # show numpy array
  #plt.imshow()
  plt.show()
  #sleep(1)
  clear_output(wait=True)

"""
##################################### CAMBIO DE GIRO
"""
bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.sin(w*t) * (np.cos(0) + 1j*np.sin(0))
Bbb = np.sin(w*t-2*np.pi/3) * (np.cos(2*np.pi/3) + 1j*np.sin(2*np.pi/3))
Bcc = np.sin(w*t+2*np.pi/3) * (np.cos(-2*np.pi/3) + 1j*np.sin(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

plt.cla() # Clear the current axes.


Baa_ref = 1.5 * np.round((np.cos(0) + 1j*np.sin(0)),4)
Bbb_ref = 1.5 * np.round((np.cos(2*np.pi/3) + 1j*np.sin(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.cos(-2*np.pi/3) + 1j*np.sin(-2*np.pi/3)),4)

ii=0;


for ii in range(1,len(t)):
  figure, axes = plt.subplots( 1 ) 
  axes.plot(x,y, c='cyan', linewidth = 2.5) 
  axes.set_aspect(1) 
  axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
  axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
  axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')
  axes.text(1.55 * np.cos(0), 1.55 * np.sin(0), 'B(aa)')
  axes.text(1.55 * np.cos(2*np.pi/3)-0.2, 1.55 * np.sin(2*np.pi/3), 'B(bb)')
  axes.text(1.55 * np.cos(-2*np.pi/3) -0.2, 1.55 * np.sin(-2*np.pi/3), 'B(cc)')

  plt.title( 'El campo magnético giratorio' ) 
  plt.xlabel('Densidad de flujo (T)')
  plt.ylabel('Densidad de flujo (T)')
  axes.plot(x,y) 
  axes.set_aspect(1) 
  plt.xlim(-2,2)
  plt.ylim(-2,2)
  h1x = [0,Baa[ii].real]
  h1y = [0,Baa[ii].imag]
  h2x = [0,Bbb[ii].real]
  h2y = [0,Bbb[ii].imag]
  h3x = [0,Bcc[ii].real]
  h3y = [0,Bcc[ii].imag]
  h4x = [0,Bnet[ii].real]
  h4y = [0,Bnet[ii].imag]
  plt.plot(h1x,h1y, c = 'black', linewidth = 2.5)
  plt.plot(h2x,h2y, c = 'b', linewidth = 2.5)
  plt.plot(h3x,h3y, c = 'r', linewidth = 2.5)
  plt.plot(h4x,h4y, c = 'y', linewidth = 2.5)
  # show numpy array
  #plt.imshow()
  plt.show()   # <- Cuello de Botella
  #sleep(1)
  clear_output(wait=True)  # <- Cuello de Botella
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-f8486bcac32b> in <module>()
#      68   # show numpy array
#      69   #plt.imshow()
# ---> 70   plt.show()
#      71   #sleep(1)
#      72   clear_output(wait=True)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/display.py in display(*objs, **kwargs)
# ...

# %%
# Tiempo aprox 7 minutos de procesamiento

# %% [markdown]
# # LINKS
#
# https://matplotlib.org/2.1.1/api/colors_api.html?highlight=color#module-matplotlib.colors
#
# https://matplotlib.org/stable/gallery/misc/hyperlinks_sgskip.html#sphx-glr-gallery-misc-hyperlinks-sgskip-py
#
# https://matplotlib.org/stable/api/lines_api.html?highlight=line#module-matplotlib.lines
#
# https://www.delftstack.com/es/howto/matplotlib/how-to-automate-plot-updates-in-matplotlib/

# %% [markdown]
# ## **-------------ANIMACIONES------------**

# %%
# %matplotlib inline

from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np
from time import sleep
from matplotlib import animation
from IPython.display import HTML

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.cos(w*t) * (np.sin(0) + 1j*np.cos(0))
Bbb = np.cos(w*t-2*np.pi/3) * (np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3))
Bcc = np.cos(w*t+2*np.pi/3) * (np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

figure, axes = plt.subplots( 1 ) 
axes.plot(x,y) 
axes.set_aspect(1) 
axes.set_xlim(-2,2)
axes.set_ylim(-2,2)
axes.set_title( 'El campo magnético giratorio' ) 
axes.set_xlabel('Densidad de flujo (T)')
axes.set_ylabel('Densidad de flujo (T)')


Baa_ref = 1.5 * np.round((np.sin(0) + 1j*np.cos(0)),4)
Bbb_ref = 1.5 * np.round((np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3)),4)

axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

ii=0;

#containers
h1, = axes.plot([0,Baa[ii].real], [0,Baa[ii].imag], c = 'black', linewidth = 2.5)
h2, = axes.plot([0,Bbb[ii].real], [0,Bbb[ii].imag], c = 'b', linewidth = 2.5)
h3, = axes.plot([0,Bcc[ii].real], [0,Bcc[ii].imag], c = 'r', linewidth = 2.5)
h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)



#print("len")
#print(len(t)) #1260


# animation function. This is called sequentially  1,len(t) n->numframes
def drawframe(n):
  for ii in range(1,len(t)):
    h1.set_xdata([0,Baa[n].real])
    h1.set_ydata([0,Baa[n].imag])
    h2.set_xdata([0,Bbb[n].real])
    h2.set_ydata([0,Bbb[n].imag])
    h3.set_xdata([0,Bcc[n].real])
    h3.set_ydata([0,Bcc[n].imag])
    h4.set_xdata([0,Bnet[n].real])
    h4.set_ydata([0,Bnet[n].imag])

    return h1,  h2, h3, h4


# blit=True re-draws only the parts that have changed.
anima = animation.FuncAnimation(figure, drawframe, frames=1260, interval=20, blit=True)
HTML(anima.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
"""
##################################################################################
----------------------------------CAMBIO DE GIRO----------------------------------
##################################################################################
"""
plt. clf() 

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.sin(w*t) * (np.cos(0) + 1j*np.sin(0))
Bbb = np.sin(w*t-2*np.pi/3) * (np.cos(2*np.pi/3) + 1j*np.sin(2*np.pi/3))
Bcc = np.sin(w*t+2*np.pi/3) * (np.cos(-2*np.pi/3) + 1j*np.sin(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

figure2, axes2 = plt.subplots( 1 ) 
axes2.plot(x,y) 
axes2.set_aspect(1) 
axes2.set_xlim(-2,2)
axes2.set_ylim(-2,2)
axes2.set_title( 'El campo magnético giratorio' ) 
axes2.set_xlabel('Densidad de flujo (T)')
axes2.set_ylabel('Densidad de flujo (T)')

Baa_ref = 1.5 * np.round((np.cos(0) + 1j*np.sin(0)),4)
Bbb_ref = 1.5 * np.round((np.cos(2*np.pi/3) + 1j*np.sin(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.cos(-2*np.pi/3) + 1j*np.sin(-2*np.pi/3)),4)

axes2.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes2.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes2.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes2.text(1.55 * np.cos(0), 1.55 * np.sin(0), 'B(aa)')
axes2.text(1.55 * np.cos(2*np.pi/3)-0.2, 1.55 * np.sin(2*np.pi/3), 'B(bb)')
axes2.text(1.55 * np.cos(-2*np.pi/3) -0.2, 1.55 * np.sin(-2*np.pi/3), 'B(cc)')

ii=0;

h1, = axes2.plot([0,Baa[ii].real], [0,Baa[ii].imag], c = 'black', linewidth = 2.5)
h2, = axes2.plot([0,Bbb[ii].real], [0,Bbb[ii].imag], c = 'b', linewidth = 2.5)
h3, = axes2.plot([0,Bcc[ii].real], [0,Bcc[ii].imag], c = 'r', linewidth = 2.5)
h4, = axes2.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)

#print("len")
#print(len(t)) #1260


# animation function. This is called sequentially  1,len(t)
def drawframe2(n):
  for ii in range(1,len(t)):
    h1.set_xdata([0,Baa[n].real])
    h1.set_ydata([0,Baa[n].imag])
    h2.set_xdata([0,Bbb[n].real])
    h2.set_ydata([0,Bbb[n].imag])
    h3.set_xdata([0,Bcc[n].real])
    h3.set_ydata([0,Bcc[n].imag])
    h4.set_xdata([0,Bnet[n].real])
    h4.set_ydata([0,Bnet[n].imag])

    return h1,  h2, h3, h4


# blit=True re-draws only the parts that have changed.
animaCG = animation.FuncAnimation(figure2, drawframe2, frames=1260, interval=20, blit=True)

HTML(animaCG.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## -------------------------------

# %% [markdown]
# Test

# %% [markdown]
# ## -------------------------------

# %% [markdown]
# # **UNIR LAS DOS ANIMACIONES**   ❌

# %%
# %matplotlib inline

from IPython.display import clear_output
import matplotlib.pyplot as plt
import numpy as np
from time import sleep
from matplotlib import animation
from IPython.display import HTML

bmax = 1 
freq = 70
T=1/freq
w = 2*np.pi*freq;
n=2

t = np.arange(0,0.015,T/1200)   
Baa = np.cos(w*t) * (np.sin(0) + 1j*np.cos(0))
Bbb = np.cos(w*t-2*np.pi/3) * (np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3))
Bcc = np.cos(w*t+2*np.pi/3) * (np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

# Calculate a circle representing the expected maximum value of Enet
circle = 1.5 * np.round(np.cos(w*t) + 1j*np.sin(w*t),4)
x = circle.real
y = circle.imag

figure, axes = plt.subplots( 1 ) 
axes.plot(x,y) 
axes.set_aspect(1) 
axes.set_xlim(-2,2)
axes.set_ylim(-2,2)
axes.set_title( 'El campo magnético giratorio' ) 
axes.set_xlabel('Densidad de flujo (T)')
axes.set_ylabel('Densidad de flujo (T)')


Baa_ref = 1.5 * np.round((np.sin(0) + 1j*np.cos(0)),4)
Bbb_ref = 1.5 * np.round((np.sin(2*np.pi/3) + 1j*np.cos(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.sin(-2*np.pi/3) + 1j*np.cos(-2*np.pi/3)),4)

axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes.text(1.55 * np.sin(0), 1.55 * np.cos(0), 'B(aa)')
axes.text(1.55 * np.sin(2*np.pi/3)+0.1, 1.55 * np.cos(2*np.pi/3), 'B(bb)')
axes.text(1.55 * np.sin(-2*np.pi/3) -0.2, 1.55 * np.cos(-2*np.pi/3), 'B(cc)')

ii=0;

#containers
h1, = axes.plot([0,Baa[ii].real], [0,Baa[ii].imag], c = 'black', linewidth = 2.5)
h2, = axes.plot([0,Bbb[ii].real], [0,Bbb[ii].imag], c = 'b', linewidth = 2.5)
h3, = axes.plot([0,Bcc[ii].real], [0,Bcc[ii].imag], c = 'r', linewidth = 2.5)
h4, = axes.plot([0,Bnet[ii].real], [0,Bnet[ii].imag], c = 'y', linewidth = 2.5)

#print("len")
#print(len(t)) #1260


"""
##################################################################################
----------------------------------CAMBIO DE GIRO----------------------------------
##################################################################################
"""
plt. clf() 

t = np.arange(0,0.015,T/1200)   
Baa = np.sin(w*t) * (np.cos(0) + 1j*np.sin(0))
Bbb = np.sin(w*t-2*np.pi/3) * (np.cos(2*np.pi/3) + 1j*np.sin(2*np.pi/3))
Bcc = np.sin(w*t+2*np.pi/3) * (np.cos(-2*np.pi/3) + 1j*np.sin(-2*np.pi/3))

# Calculamos Enet
Bnet = np.round(Baa + Bbb + Bcc,4)

figure, axes2 = plt.subplots( 1 ) 
axes.plot(x,y) 
axes.set_aspect(1) 
axes.set_xlim(-2,2)
axes.set_ylim(-2,2)
axes.set_title( 'El campo magnético giratorio' ) 
axes.set_xlabel('Densidad de flujo (T)')
axes.set_ylabel('Densidad de flujo (T)')

Baa_ref = 1.5 * np.round((np.cos(0) + 1j*np.sin(0)),4)
Bbb_ref = 1.5 * np.round((np.cos(2*np.pi/3) + 1j*np.sin(2*np.pi/3)),4)
Bcc_ref = 1.5 * np.round((np.cos(-2*np.pi/3) + 1j*np.sin(-2*np.pi/3)),4)

axes.plot([0,Baa_ref.real], [0,Baa_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bbb_ref.real], [0,Bbb_ref.imag], linestyle = 'dotted', c = 'r')
axes.plot([0,Bcc_ref.real], [0,Bcc_ref.imag], linestyle = 'dotted', c = 'r')

axes.text(1.55 * np.cos(0), 1.55 * np.sin(0), 'B(aa)')
axes.text(1.55 * np.cos(2*np.pi/3)-0.2, 1.55 * np.sin(2*np.pi/3), 'B(bb)')
axes.text(1.55 * np.cos(-2*np.pi/3) -0.2, 1.55 * np.sin(-2*np.pi/3), 'B(cc)')


#print("len")
#print(len(t)) #1260


# animation function. This is called sequentially  1,len(t)
def drawframes(n):
  for ii in range(1,len(t)):
    h1.set_xdata([0,Baa[n].real])
    h1.set_ydata([0,Baa[n].imag])
    h2.set_xdata([0,Bbb[n].real])
    h2.set_ydata([0,Bbb[n].imag])
    h3.set_xdata([0,Bcc[n].real])
    h3.set_ydata([0,Bcc[n].imag])
    h4.set_xdata([0,Bnet[n].real])
    h4.set_ydata([0,Bnet[n].imag])

    print("n: ")
    print(n)

    return h1,  h2, h3, h4

# blit=True re-draws only the parts that have changed.
animacALL = animation.FuncAnimation(figure2, drawframes, frames=2520, interval=20, blit=True)

#HTML(animacALL.to_html5_video())
# Out:
# n:
# 0
